# %% [markdown]
# # SyftBox SDK Development Testing
#
# This notebook is for testing and validating the SyftBox SDK during development.

# %% [markdown]
# # Quickstart

# %%
# %%capture output --no-stderr

# Install async module
# !uv pip install nest_asyncio

# %%
# Import the SDK
import syft_hub as sh
# import nest_asyncio
# import httpx
import logging
import os

# %%
# Import client
from syft_hub import Client
from syft_hub.utils.logger import get_logger

# %%
# define utilities
# nest_asyncio.apply()
logger = get_logger()
logging.getLogger('syft_hub').setLevel(logging.INFO)
logger.success("Logger initialized successfully!")
# Out:
# 2025-09-05 17:02:49 - syft_hub - SUCCESS - Logger initialized successfully!

# %%
# Initialize client
client = Client()
# Out:
# 2025-09-05 17:02:49 - syft_hub.core.config - INFO - Using config credentials at path: /Users/callisezenwaka/.syftbox/config.json
# 2025-09-05 17:02:49 - syft_hub.main - INFO - Found existing accounting credentials for callis@openmined.org
# 2025-09-05 17:02:49 - syft_hub.main - INFO - Client initialized for callis@openmined.org

# %%
# Discover services explicitly 
services = client.list_services(service_type="chat")
print(f"Found {len(services)} services")
# Out:
# 2025-09-05 17:02:56 - syft_hub.services.health - INFO - Batch health check completed in 6.10s for 10 services
# Found 10 services

# %%
# Format services
print(f"{'Name':<20} {'Datasite':<40} {'Tags':<35} {'Services':<25}")
print("-" * 120)
for service in services:
    enabled_services = [s.type.value for s in service.services if s.enabled]
    # tags_str = ", ".join(service.tags[:2])
    tags_str = ", ".join(service.tags[:2])
    display_tags = "--" if not tags_str else tags_str
    services_str = ", ".join(enabled_services)
    print(f"{service.name:<20} {service.datasite:<40} {display_tags:<35} {services_str:<25}")
# Out:
# Name                 Datasite                                 Tags                                Services
# ------------------------------------------------------------------------------------------------------------------------
# keelan-test-3        kj@kj.dev                                test                                chat, search
# pal-8                afdolriski@gmail.com                     --                                  chat, search
# sota-free            callis@openmined.org                     chat, search                        chat, search
# carl-model           callis@openmined.org                     Chat, Search                        chat, search
# carl-claude          callis@openmined.org                     chat, search                        chat, search
# carl-free            callis@openmined.org                     chat, search                        chat, search
# ...

# %%
# show services
services.show_services()
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>SyftBox Services</title>
#     <style>
#     body {
#         background-color: #ffffff;
#         color: #000000;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#     }
#
#     @keyframes float {
#         0%, 100% { transform: translateY(0px); }
#         50% { transform: translateY(-8px); }
#     }
#
#     .syftbox-logo {
#         animation: float 3s ease-in-out infinite;
#         filter: drop-shadow(0 4px 12px rgba(0, 0, 0, 0.15));
#     }
#
#     .progress-bar-gradient {
#         background: linear-gradient(90deg, #3b82f6 0%, #10b981 100%);
#         transition: width 0.4s ease-out;
#         border-radius: 3px;
#     }
#
#     #syft_services_548b4bef * {
#         margin: 0;
#         padding: 0;
#         box-sizing: border-box;
# ...
